# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\hp\Desktop\pandas p\sir csv\Bengaluru_House_Data.csv")

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.shape
# Out:
# (13320, 9)

# %%
df['area_type']
# Out:
# 0        Super built-up  Area
# 1                  Plot  Area
# 2              Built-up  Area
# 3        Super built-up  Area
# 4        Super built-up  Area
#                  ...
# 13315          Built-up  Area
# 13316    Super built-up  Area
# 13317          Built-up  Area
# 13318    Super built-up  Area
# 13319    Super built-up  Area
# Name: area_type, Length: 13320, dtype: object

# %%
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', nan, '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
df['society'].unique()
# Out:
# array(['Coomee ', 'Theanmp', nan, ..., 'SJovest', 'ThhtsV ', 'RSntsAp'],
#       dtype=object)

# %%
df['society'].value_counts()
# Out:
# GrrvaGr    80
# PrarePa    76
# Sryalan    59
# Prtates    59
# GMown E    56
#            ..
# Amionce     1
# JaghtDe     1
# Jauraht     1
# Brity U     1
# RSntsAp     1
# Name: society, Length: 2688, dtype: int64

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df['added_vlaue']=df['price']*2

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price  added_vlaue
# ...

# %%
df.drop('price',axis=1)
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony  added_vlaue
# 0          2 BHK  Coomee        1056   2.0      1.0        78.14
# ...

# %%
df['Price']=df['added_vlaue']/2

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price  added_vlaue  \
# ...

# %%
df.drop('Price',axis=1,inplace=True)

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price  added_vlaue
# ...

# %%
df.drop('bath',axis=1)
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  balcony   price  added_vlaue
# 0          2 BHK  Coomee        1056      1.0   39.07        78.14
# ...

# %%
sk=df.drop('location',axis=1)

# %%
sk
# Out:
#                   area_type   availability       size  society total_sqft  \
# 0      Super built-up  Area         19-Dec      2 BHK  Coomee        1056
# 1                Plot  Area  Ready To Move  4 Bedroom  Theanmp       2600
# 2            Built-up  Area  Ready To Move      3 BHK      NaN       1440
# 3      Super built-up  Area  Ready To Move      3 BHK  Soiewre       1521
# 4      Super built-up  Area  Ready To Move      2 BHK      NaN       1200
# ...                     ...            ...        ...      ...        ...
# 13315        Built-up  Area  Ready To Move  5 Bedroom  ArsiaEx       3453
# 13316  Super built-up  Area  Ready To Move      4 BHK      NaN       3600
# 13317        Built-up  Area  Ready To Move      2 BHK  Mahla T       1141
# 13318  Super built-up  Area         18-Jun      4 BHK  SollyCl       4689
# 13319  Super built-up  Area  Ready To Move      1 BHK      NaN        550
#
#        bath  balcony   price  added_vlaue
# ...

# %%
sk.drop('added_vlaue',axis=1,inplace=True)

# %%
sk
# Out:
#                   area_type   availability       size  society total_sqft  \
# 0      Super built-up  Area         19-Dec      2 BHK  Coomee        1056
# 1                Plot  Area  Ready To Move  4 Bedroom  Theanmp       2600
# 2            Built-up  Area  Ready To Move      3 BHK      NaN       1440
# 3      Super built-up  Area  Ready To Move      3 BHK  Soiewre       1521
# 4      Super built-up  Area  Ready To Move      2 BHK      NaN       1200
# ...                     ...            ...        ...      ...        ...
# 13315        Built-up  Area  Ready To Move  5 Bedroom  ArsiaEx       3453
# 13316  Super built-up  Area  Ready To Move      4 BHK      NaN       3600
# 13317        Built-up  Area  Ready To Move      2 BHK  Mahla T       1141
# 13318  Super built-up  Area         18-Jun      4 BHK  SollyCl       4689
# 13319  Super built-up  Area  Ready To Move      1 BHK      NaN        550
#
#        bath  balcony   price
# 0       2.0      1.0   39.07
# ...

# %%
sk.drop(3)
# Out:
#                   area_type   availability       size  society total_sqft  \
# 0      Super built-up  Area         19-Dec      2 BHK  Coomee        1056
# 1                Plot  Area  Ready To Move  4 Bedroom  Theanmp       2600
# 2            Built-up  Area  Ready To Move      3 BHK      NaN       1440
# 4      Super built-up  Area  Ready To Move      2 BHK      NaN       1200
# 5      Super built-up  Area  Ready To Move      2 BHK  DuenaTa       1170
# ...                     ...            ...        ...      ...        ...
# 13315        Built-up  Area  Ready To Move  5 Bedroom  ArsiaEx       3453
# 13316  Super built-up  Area  Ready To Move      4 BHK      NaN       3600
# 13317        Built-up  Area  Ready To Move      2 BHK  Mahla T       1141
# 13318  Super built-up  Area         18-Jun      4 BHK  SollyCl       4689
# 13319  Super built-up  Area  Ready To Move      1 BHK      NaN        550
#
#        bath  balcony   price
# 0       2.0      1.0   39.07
# ...

# %%
sk.drop(2)
# Out:
#                   area_type   availability       size  society total_sqft  \
# 0      Super built-up  Area         19-Dec      2 BHK  Coomee        1056
# 1                Plot  Area  Ready To Move  4 Bedroom  Theanmp       2600
# 3      Super built-up  Area  Ready To Move      3 BHK  Soiewre       1521
# 4      Super built-up  Area  Ready To Move      2 BHK      NaN       1200
# 5      Super built-up  Area  Ready To Move      2 BHK  DuenaTa       1170
# ...                     ...            ...        ...      ...        ...
# 13315        Built-up  Area  Ready To Move  5 Bedroom  ArsiaEx       3453
# 13316  Super built-up  Area  Ready To Move      4 BHK      NaN       3600
# 13317        Built-up  Area  Ready To Move      2 BHK  Mahla T       1141
# 13318  Super built-up  Area         18-Jun      4 BHK  SollyCl       4689
# 13319  Super built-up  Area  Ready To Move      1 BHK      NaN        550
#
#        bath  balcony   price
# 0       2.0      1.0   39.07
# ...

# %%
sk
# Out:
#                   area_type   availability       size  society total_sqft  \
# 0      Super built-up  Area         19-Dec      2 BHK  Coomee        1056
# 1                Plot  Area  Ready To Move  4 Bedroom  Theanmp       2600
# 2            Built-up  Area  Ready To Move      3 BHK      NaN       1440
# 3      Super built-up  Area  Ready To Move      3 BHK  Soiewre       1521
# 4      Super built-up  Area  Ready To Move      2 BHK      NaN       1200
# ...                     ...            ...        ...      ...        ...
# 13315        Built-up  Area  Ready To Move  5 Bedroom  ArsiaEx       3453
# 13316  Super built-up  Area  Ready To Move      4 BHK      NaN       3600
# 13317        Built-up  Area  Ready To Move      2 BHK  Mahla T       1141
# 13318  Super built-up  Area         18-Jun      4 BHK  SollyCl       4689
# 13319  Super built-up  Area  Ready To Move      1 BHK      NaN        550
#
#        bath  balcony   price
# 0       2.0      1.0   39.07
# ...

# %%
sk.drop(['availability','society','balcony'],axis=1)
# Out:
#                   area_type       size total_sqft  bath   price
# 0      Super built-up  Area      2 BHK       1056   2.0   39.07
# 1                Plot  Area  4 Bedroom       2600   5.0  120.00
# 2            Built-up  Area      3 BHK       1440   2.0   62.00
# 3      Super built-up  Area      3 BHK       1521   3.0   95.00
# 4      Super built-up  Area      2 BHK       1200   2.0   51.00
# ...                     ...        ...        ...   ...     ...
# 13315        Built-up  Area  5 Bedroom       3453   4.0  231.00
# 13316  Super built-up  Area      4 BHK       3600   5.0  400.00
# 13317        Built-up  Area      2 BHK       1141   2.0   60.00
# 13318  Super built-up  Area      4 BHK       4689   4.0  488.00
# 13319  Super built-up  Area      1 BHK        550   1.0   17.00
#
# [13320 rows x 5 columns]

# %%
sk.drop(columns=['availability','society','balcony'])
# Out:
#                   area_type       size total_sqft  bath   price
# 0      Super built-up  Area      2 BHK       1056   2.0   39.07
# 1                Plot  Area  4 Bedroom       2600   5.0  120.00
# 2            Built-up  Area      3 BHK       1440   2.0   62.00
# 3      Super built-up  Area      3 BHK       1521   3.0   95.00
# 4      Super built-up  Area      2 BHK       1200   2.0   51.00
# ...                     ...        ...        ...   ...     ...
# 13315        Built-up  Area  5 Bedroom       3453   4.0  231.00
# 13316  Super built-up  Area      4 BHK       3600   5.0  400.00
# 13317        Built-up  Area      2 BHK       1141   2.0   60.00
# 13318  Super built-up  Area      4 BHK       4689   4.0  488.00
# 13319  Super built-up  Area      1 BHK        550   1.0   17.00
#
# [13320 rows x 5 columns]

# %%
df=pd.read_csv(r"C:\Users\hp\Desktop\pandas p\Churn Modeling.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
col=[col for col in df.columns if col not in ['Gender','Age','Balance']]

# %%
col
# Out:
# ['RowNumber',
#  'CustomerId',
#  'Surname',
#  'CreditScore',
#  'Geography',
#  'Tenure',
#  'NumOfProducts',
#  'HasCrCard',
#  'IsActiveMember',
#  'EstimatedSalary',
#  'Exited']

# %%
sk=df[col]

# %%
sk
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Tenure  \
# 0             1    15634602   Hargrave          619    France       2
# 1             2    15647311       Hill          608     Spain       1
# 2             3    15619304       Onio          502    France       8
# 3             4    15701354       Boni          699    France       1
# 4             5    15737888   Mitchell          850     Spain       2
# ...         ...         ...        ...          ...       ...     ...
# 9995       9996    15606229   Obijiaku          771    France       5
# 9996       9997    15569892  Johnstone          516    France      10
# 9997       9998    15584532        Liu          709    France       7
# 9998       9999    15682355  Sabbatini          772   Germany       3
# 9999      10000    15628319     Walker          792    France       4
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
col=[col for col in sk.columns if not col.startswith('Surname')]

# %%
col
# Out:
# ['RowNumber',
#  'CustomerId',
#  'CreditScore',
#  'Geography',
#  'Tenure',
#  'NumOfProducts',
#  'HasCrCard',
#  'IsActiveMember',
#  'EstimatedSalary',
#  'Exited']

# %%
sk[col]
# Out:
#       RowNumber  CustomerId  CreditScore Geography  Tenure  NumOfProducts  \
# 0             1    15634602          619    France       2              1
# 1             2    15647311          608     Spain       1              1
# 2             3    15619304          502    France       8              3
# 3             4    15701354          699    France       1              2
# 4             5    15737888          850     Spain       2              1
# ...         ...         ...          ...       ...     ...            ...
# 9995       9996    15606229          771    France       5              2
# 9996       9997    15569892          516    France      10              1
# 9997       9998    15584532          709    France       7              1
# 9998       9999    15682355          772   Germany       3              2
# 9999      10000    15628319          792    France       4              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
df=pd.read_csv(r"C:\Users\hp\Desktop\pandas p\sir csv\Bengaluru_House_Data.csv")

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 5      Super built-up  Area  Ready To Move                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 13313  Super built-up  Area  Ready To Move               Uttarahalli
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# society         0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 5      Super built-up  Area  Ready To Move                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 13313  Super built-up  Area  Ready To Move               Uttarahalli
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df["New_Size"]=df['size'].map(lambda x: x.split(' ')[0])

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 5      Super built-up  Area  Ready To Move                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 13313  Super built-up  Area  Ready To Move               Uttarahalli
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price New_Size
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07        2
# ...

# %%
df=pd.read_csv('tam.txt')

# %%
df
# Out:
#   name  age     sal
# 0  abc   23  232121
# 1  xyz   34   45332
# 2  pqr   31  342322

# %%
df1=df.to_csv("sample.csv")

# %%
df=pd.read_csv("sample.csv")

# %%
df
# Out:
#    Unnamed: 0 name  age     sal
# 0           0  abc   23  232121
# 1           1  xyz   34   45332
# 2           2  pqr   31  342322

# %%
s=pd.Series(['m','f','m'],name='gen')

# %%
s
# Out:
# 0    m
# 1    f
# 2    m
# Name: gen, dtype: object

# %%
df1=pd.concat([df,s],axis=1)

# %%
df1
# Out:
#    Unnamed: 0 name  age     sal gen
# 0           0  abc   23  232121   m
# 1           1  xyz   34   45332   f
# 2           2  pqr   31  342322   m

# %%
df1['New_gen']=df1['gen'].map({'m':1,'f':0})

# %%
df1
# Out:
#    Unnamed: 0 name  age     sal gen  New_gen
# 0           0  abc   23  232121   m        1
# 1           1  xyz   34   45332   f        0
# 2           2  pqr   31  342322   m        1

# %%
def add(r):
    if r=='m':
        return 1
    elif r=='f':
        return 0
    else:
        return none

# %%
df1['New1_Gen']=df1['gen'].map(add)

# %%
df1
# Out:
#    Unnamed: 0 name  age     sal gen  New_gen  New1_Gen
# 0           0  abc   23  232121   m        1         1
# 1           1  xyz   34   45332   f        0         0
# 2           2  pqr   31  342322   m        1         1

# %%
df1['New2_Gen']=df1['gen'].map(lambda x : 1 if x=='m' else 0)

# %%
df1
# Out:
#    Unnamed: 0 name  age     sal gen  New_gen  New1_Gen  New2_Gen
# 0           0  abc   23  232121   m        1         1         1
# 1           1  xyz   34   45332   f        0         0         0
# 2           2  pqr   31  342322   m        1         1         1
