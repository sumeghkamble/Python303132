# %%
A={
  "employees": [
    {
      "name": "John Doe",
      "age": 30,
      "department": "Engineering",
      "projects": ["Project A", "Project B"]
    },
    {
      "name": "Jane Smith",
      "age": 35,
      "department": "Marketing",
      "projects": ["Project C"]
    },
    {
      "name": "Alice Johnson",
      "age": 25,
      "department": "Finance",
      "projects": ["Project B", "Project D"]
    }
  ]
}

# %%
import pandas as pd

# %%
df=pd.read_json(r"C:\Users\hp\Desktop\pandas practise\New folder\users_1k.json")

# %%
df
# Out:
#       id       name         city  age  \
# 0      0     Daniel    San Diego   48
# 1      1      Sarah      Lahaina   39
# 2      2  Charlotte     Honolulu   49
# 3      3       Noah    St. Louis   89
# 4      4     Daniel    San Diego   87
# ..   ...        ...          ...  ...
# 995  995        Mia       Boston   85
# 996  996        Leo   Charleston   39
# 997  997       Nora      Chicago   62
# 998  998     Amelia    St. Louis   25
# 999  999     Sophie  Miami Beach   19
#
#                                                friends
# 0    [{'name': 'Charlotte', 'hobbies': ['Quilting',...
# 1    [{'name': 'Mia', 'hobbies': ['Church Activitie...
# 2    [{'name': 'Chris', 'hobbies': ['Socializing', ...
# 3    [{'name': 'Sarah', 'hobbies': ['Board Games', ...
# 4    [{'name': 'Michael', 'hobbies': ['Genealogy', ...
# ..                                                 ...
# 995  [{'name': 'Daniel', 'hobbies': ['Church Activi...
# 996  [{'name': 'Evy', 'hobbies': ['Running', 'Paint...
# ...

# %%
df[df['age']>40]
# Out:
#       id       name       city  age  \
# 0      0     Daniel  San Diego   48
# 2      2  Charlotte   Honolulu   49
# 3      3       Noah  St. Louis   89
# 4      4     Daniel  San Diego   87
# 5      5     Amelia   Portland   57
# ..   ...        ...        ...  ...
# 992  992      Mateo  Las Vegas   75
# 993  993     Sophie     Austin   54
# 994  994       Levi  San Diego   51
# 995  995        Mia     Boston   85
# 997  997       Nora    Chicago   62
#
#                                                friends
# 0    [{'name': 'Charlotte', 'hobbies': ['Quilting',...
# 2    [{'name': 'Chris', 'hobbies': ['Socializing', ...
# 3    [{'name': 'Sarah', 'hobbies': ['Board Games', ...
# 4    [{'name': 'Michael', 'hobbies': ['Genealogy', ...
# 5    [{'name': 'Noah', 'hobbies': ['Watching Sports...
# ..                                                 ...
# 992  [{'name': 'Grace', 'hobbies': ['Church Activit...
# 993  [{'name': 'Liam', 'hobbies': ['Board Games', '...
# ...

# %%
df.shape
# Out:
# (1000, 5)

# %%
df.isnull().sum()
# Out:
# id         0
# name       0
# city       0
# age        0
# friends    0
# dtype: int64

# %%
new_json=df[df['city']=='Boston']

# %%
new_json.to_json('boston_json')
